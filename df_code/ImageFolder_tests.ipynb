# %%
from google.colab import drive
drive.mount("/content/MyDrive/")
# Out:
# Mounted at /content/MyDrive/

# %%
cd /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main/helpers/
# Out:
# /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main/helpers

# %%
from torchvision import transforms
from augmentation import Aug

mean = [0.485, 0.456, 0.406] #[0.4718, 0.3467, 0.3154] DFDC dataset mean and standard #RGB
std = [0.229, 0.224, 0.225]  #[0.1656, 0.1432, 0.1364]

data_transforms = {
    'train': transforms.Compose([
        Aug(),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'validation': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
}

# %%
from torchvision import datasets
import os

# %%
data_dir = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test"

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'validation', 'test']}
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-ad86d762659a> in <module>()
#       3 image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
#       4                                           data_transforms[x])
# ----> 5                   for x in ['train', 'validation', 'test']}
#
# <ipython-input-5-ad86d762659a> in <dictcomp>(.0)
#       3 image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
#       4                                           data_transforms[x])
# ----> 5                   for x in ['train', 'validation', 'test']}
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     254                                           transform=transform,
# ...

# %%
cd /content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test
# Out:
# /content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test

# %%
cd train
# Out:
# /content/MyDrive/My Drive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test/train

# %%
cd fake
# Out:
# /content/MyDrive/My Drive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test/train/fake

# %%
ls
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# lqdfxvghdz_muhgbpklnc_0.jpg   ypwvtnpygr_xzvrgckqkz_0.jpg
# lqdfxvghdz_muhgbpklnc_1.jpg   ypwvtnpygr_xzvrgckqkz_1.jpg
# lqdfxvghdz_muhgbpklnc_2.jpg   ypwvtnpygr_xzvrgckqkz_2.jpg
# lqdfxvghdz_muhgbpklnc_3.jpg   ypwvtnpygr_xzvrgckqkz_3.jpg
# lqdfxvghdz_muhgbpklnc_4.jpg   ypwvtnpygr_xzvrgckqkz_4.jpg
# lqgmoiswmf_kudzyixxsm_0.jpg   ypwvtnpygr_xzvrgckqkz_5.jpg
# lqgmoiswmf_kudzyixxsm_1.jpg   ypwvtnpygr_xzvrgckqkz_6.jpg
# lqgmoiswmf_kudzyixxsm_2.jpg   ypwvtnpygr_xzvrgckqkz_7.jpg
# lqgmoiswmf_kudzyixxsm_3.jpg   ypwvtnpygr_xzvrgckqkz_8.jpg
# lqgmoiswmf_kudzyixxsm_4.jpg   ypwvtnpygr_xzvrgckqkz_9.jpg
# lqgmoiswmf_kudzyixxsm_5.jpg   ypxtnfpilb_immxgtbwsb_0.jpg
# lqgmoiswmf_kudzyixxsm_6.jpg   ypxtnfpilb_immxgtbwsb_1.jpg
# lqgmoiswmf_kudzyixxsm_7.jpg   ypzhswhskq_vgswacpvls_0.jpg
# lqibltouvk_lqpqpgdbgr_0.jpg   ypzhswhskq_vgswacpvls_1.jpg
# lqibltouvk_lqpqpgdbgr_1.jpg   yqazucouzj_lmgbrxnyjk_0.jpg
# ...

# %%
data_dir = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test"

train = datasets.ImageFolder(os.path.join(data_dir, "train"), data_transforms["train"])

# %%
train.imgs

# %%
validation = datasets.ImageFolder(os.path.join(data_dir, "validation"), data_transforms["validation"])

# %%
test = datasets.ImageFolder(os.path.join(data_dir, "test"), data_transforms["test"])

# %%
image_datasets = {
  "train": train,
  "validation": validation,
  "test": test
}

# %%
image_datasets["validation"]
# Out:
# Dataset ImageFolder
#     Number of datapoints: 64787
#     Root location: /content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test/validation
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
