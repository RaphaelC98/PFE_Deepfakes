# %%
# !nvidia-smi
# Out:
# Wed Jun  9 05:19:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvidia-smi
from google.colab import drive
drive.mount("/content/MyDrive/")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
# !pip install einops

# %%
cd /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main/
# Out:
# /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main

# %%
# !python cvit_train.py --dir=/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train_validation_test --epoch=1 --cession='g' --batch=32 --rate=0.0001 --resume=cvit_dfd_epoch_1_batch_1500.pth #--decay==0.0000001 #--version
# Out:
# => loading checkpoint 'cvit_dfd_epoch_1_batch_1500.pth'
# => loaded checkpoint 'cvit_dfd_epoch_1_batch_1500.pth' (epoch 1)
# Epoch 1/0
# ----------
# train  batch: 0 loss: 0.68975830078125
# Train Epoch: 1 [0/92463 (0%)]	Loss: 0.689758
# train  batch: 100 loss: 3.725290076417309e-09
# Train Epoch: 1 [3200/92463 (3%)]	Loss: 0.000000
# train  batch: 200 loss: 0.0
# Train Epoch: 1 [6400/92463 (7%)]	Loss: 0.000000
# train  batch: 300 loss: 0.0
# Train Epoch: 1 [9600/92463 (10%)]	Loss: 0.000000
# train  batch: 400 loss: 3.725290076417309e-09
# Train Epoch: 1 [12800/92463 (14%)]	Loss: 0.000000
# train  batch: 500 loss: 3.725290076417309e-09
# Train Epoch: 1 [16000/92463 (17%)]	Loss: 0.000000
# train  batch: 600 loss: 0.0
# Train Epoch: 1 [19200/92463 (21%)]	Loss: 0.000000
# train  batch: 700 loss: 0.0
# Train Epoch: 1 [22400/92463 (24%)]	Loss: 0.000000
# train  batch: 800 loss: 0.0
# Train Epoch: 1 [25600/92463 (28%)]	Loss: 0.000000
# train  batch: 900 loss: 7.450580152834618e-09
# ...

# %%
#epoch 3 : Acc 0.7586  
#epoch 4 : Acc: 0.6741  validation loss 0.4611 Acc : 0.7726
#epoch 5 : not done #monter la sauvegarde de 100 à 500 batch + mettre une sauvegarde finale>done  
#epoch 6 : not done   
#epoch 7 : not done
#epoch 8 : not done
#epoch 9 : not done 
#epoch 10 : not done
#epoch 11 : not done
#epoch 12 : not done 
#epoch 13 : not done
#epoch 14 : not done
#epoch 15 : not done 
#epoch 16 : not done
#epoch 17 : not done
#epoch 18 : not done 
#epoch 19 : not done
#epoch 20 : not done
#epoch 21 : not done

# %%
cd /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main/helpers/
# Out:
# /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main/helpers

# %%
from torchvision import transforms
from augmentation import Aug

mean = [0.485, 0.456, 0.406] #[0.4718, 0.3467, 0.3154] DFDC dataset mean and standard #RGB
std = [0.229, 0.224, 0.225]  #[0.1656, 0.1432, 0.1364]

data_transforms = {
    'train': transforms.Compose([
        Aug(),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'validation': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
}

# %%
from torchvision import datasets
import os

# %%
data_dir = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited"

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'validation', 'test']}

# %%
# %cd "content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited/train"
# Out:
# [Errno 2] No such file or directory: 'content/MyDrive/MyDrive/PFE_Deepfakes'
# /content/MyDrive/MyDrive/PFE_Deepfakes/df_code/CViT_main/CViT_main/helpers

# %%
for i in range(30) : 
  print(image_datasets["train"][-i*100][1])
# Out:
# 0
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35

# %%
# !python cvit_train.py --dir=/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited --epoch=3 --cession='g' --batch=32 --rate=0.0001 #--decay==0.0000001 #--version
# Out:
# Epoch 0/2
# ----------
# THCudaCheck FAIL file=/pytorch/aten/src/THC/generic/THCTensorMath.cu line=29 error=710 : device-side assert triggered
# Traceback (most recent call last):
#   File "cvit_train.py", line 304, in <module>
#     train_gpu(model, criterion, optimizer, scheduler, num_epochs, min_val_loss) #Train using GPU.
#   File "cvit_train.py", line 230, in train_gpu
#     loss.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py", line 147, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# RuntimeError: cuda runtime error (710) : device-side assert triggered at /pytorch/aten/src/THC/generic/THCTensorMath.cu:29
# ...
