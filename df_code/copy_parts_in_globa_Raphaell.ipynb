# %%
from google.colab import drive
drive.mount("/content/MyDrive/")
# Out:
# Mounted at /content/MyDrive/

# %%
import os
import shutil

# %%
path = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited"
dirs = os.listdir(path)

for dir in dirs : 
  print(dir)
  dir_path = os.path.join(path, dir)
  parts = os.listdir(dir_path)
  for part in parts : 
    print(part)
    part_path = os.path.join(path, dir, part)
    fake_folder = os.listdir(os.path.join(part_path, 'fake'))
    real_folder = os.listdir(os.path.join(part_path, 'real'))
    print('fake')
    f=0
    for item in fake_folder : 
      f+=1
    print(f)
    print('real')
    r=0
    for item in real_folder : 
      r+=1
    print(r)
# Out:
# train
# training_face_4
# fake
# 1244
# real
# 1229
# training_face_5
# fake
# 2217
# real
# 2294
# training_face_6
# fake
# 2391
# real
# 2598
# training_face_7
# fake
# 2446
# real
# 2460
# training_face_8
# fake
# 2309
# real
# 2303
# training_face_9
# fake
# 2140
# real
# 2206
# training_face_10
# fake
# 2755
# real
# 2687
# training_face_11
# fake
# 2995
# real
# 2994
# training_face_12
# fake
# 2056
# real
# 2166
# training_face_13
# fake
# 2981
# real
# 3039
# training_face_14
# fake
# 2515
# real
# 2600
# training_face_15
# fake
# 3168
# real
# 3206
# training_face_16
# fake
# 2580
# real
# 2436
# training_face_17
# fake
# 3419
# real
# 3463
# training_face_18
# fake
# 3196
# real
# 3276
# training_face_19
# fake
# 3469
# real
# 3472
# training_face_20
# fake
# 3000
# real
# 2974
# training_face_21
# fake
# 2636
# real
# 2513
# training_face_22
# fake
# 3330
# real
# 3478
# training_face_23
# fake
# 2937
# real
# 3026
# training_face_24
# fake
# 2833
# real
# 2920
# ...

# %%
path = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited"
dirs = os.listdir(path)

for dir in dirs : 
  print(dir)
  dir_path = os.path.join(path, dir)
  parts = os.listdir(dir_path)
  for part in parts : 
    print(part)
    part_path = os.path.join(path, dir, part)
    fake_folder = os.listdir(os.path.join(part_path, 'fake'))
    real_folder = os.listdir(os.path.join(part_path, 'real'))

    print('fake')
    f= 0
    for item in fake_folder : 
      new_path = os.path.join(path, "train_validation_test", dir,"fake", item)
      if not os.path.isfile(new_path) : 
        f+=1
    print(f)

    r= 0
    print('real')
    for item in real_folder : 
      new_path = os.path.join(path, "train_validation_test", dir,"real", item)
      os.path.isfile(new_path)
      if not os.path.isfile(new_path) :
        r+=1
    print(r)

# %%
path = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited"
dirs = os.listdir(path)

for dir in dirs : 
  print(dir)
  dir_path = os.path.join(path, dir)
  parts = os.listdir(dir_path)
  for part in parts : 
    print(part)
    part_path = os.path.join(path, dir, part)
    fake_folder = os.listdir(os.path.join(part_path, 'fake'))
    real_folder = os.listdir(os.path.join(part_path, 'real'))

    print('fake')
    f= 0
    f2= 0
    for item in fake_folder : 
      old_path = os.path.join(part_path, 'fake', item)
      new_path = os.path.join(path, "train_validation_test", dir,"fake", item)
      if not os.path.isfile(new_path) : 
        shutil.copyfile(old_path, new_path)
        f+=1
      f2+=1
    print(f, "/", f2)

    r= 0
    r2 = 0
    print('real')
    for item in real_folder : 
      old_path = os.path.join(part_path, 'real', item)
      new_path = os.path.join(path, "train_validation_test", dir,"real", item)
      os.path.isfile(new_path)
      if not os.path.isfile(new_path) : 
        shutil.copyfile(old_path, new_path)
        r+=1
      r2+=1
    print(r, "/", r2)

#finished 28 began 29
# Out:
# train
# training_face_4
# fake
# 1244 / 1244
# real
# 1229 / 1229
# training_face_5
# fake
# 2217 / 2217
# real
# 2294 / 2294
# training_face_6
# fake
# 2391 / 2391
# real
# 2598 / 2598
# training_face_7
# fake
# 2446 / 2446
# real
# 2460 / 2460
# training_face_8
# fake
# 2309 / 2309
# real
# 2303 / 2303
# training_face_9
# fake
# 2140 / 2140
# real
# 2206 / 2206
# training_face_10
# fake
# 2755 / 2755
# real
# 2687 / 2687
# training_face_11
# fake
# 2995 / 2995
# real
# 2994 / 2994
# training_face_12
# fake
# 2056 / 2056
# real
# 2166 / 2166
# training_face_13
# fake
# 2981 / 2981
# real
# 3039 / 3039
# training_face_14
# fake
# 2515 / 2515
# real
# 2600 / 2600
# training_face_15
# fake
# 3168 / 3168
# real
# 3206 / 3206
# training_face_16
# fake
# 2580 / 2580
# real
# 2436 / 2436
# training_face_17
# fake
# 3419 / 3419
# real
# 3463 / 3463
# training_face_18
# fake
# 3196 / 3196
# real
# 3276 / 3276
# training_face_19
# fake
# 3469 / 3469
# real
# 3472 / 3472
# training_face_20
# ...

# %%
path = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited"
dirs = os.listdir(path)

for dir in dirs : 
  print(dir)
  dir_path = os.path.join(path, dir)
  parts = os.listdir(dir_path)
  for part in parts : 
    print(part)
    part_number = part[-2:].replace("_","")
    print(part_number)
    if int(part_number) > 28 : 
      part_path = os.path.join(path, dir, part)
      fake_folder = os.listdir(os.path.join(part_path, 'fake'))
      real_folder = os.listdir(os.path.join(part_path, 'real'))
      print('fake')
      f=0
      for item in fake_folder : 
        f+=1
      print(f)
      print('real')
      r=0
      for item in real_folder : 
        r+=1
      print(r)

# %%
path = "/content/MyDrive/MyDrive/PFE_Deepfakes/datasets/DFDC/splited"
dirs = os.listdir(path)

for dir in dirs : 
  print(dir)
  dir_path = os.path.join(path, dir)
  parts = os.listdir(dir_path)
  for part in parts : 
    print(part)
    part_number = part[-2:].replace("_","")
    print(part_number)
    if int(part_number) > 28 : 
      part_path = os.path.join(dir_path, part)
      fake_folder = os.listdir(os.path.join(part_path, 'fake'))
      real_folder = os.listdir(os.path.join(part_path, 'real'))

      print('fake')
      f= 0
      f2= 0
      for item in fake_folder : 
        old_path = os.path.join(part_path, 'fake', item)
        new_path = os.path.join(path, "train_validation_test", dir,"fake", item)
        if not os.path.isfile(new_path) : 
          shutil.copyfile(old_path, new_path)
          f+=1
        f2+=1
      print(f, "/", f2)

      r= 0
      r2 = 0
      print('real')
      for item in real_folder : 
        old_path = os.path.join(part_path, 'real', item)
        new_path = os.path.join(path, "train_validation_test", dir,"real", item)
        os.path.isfile(new_path)
        if not os.path.isfile(new_path) : 
          shutil.copyfile(old_path, new_path)
          r+=1
        r2+=1
      print(r, "/", r2)
# Out:
# train
# training_face_4
# 4
# training_face_5
# 5
# training_face_6
# 6
# training_face_7
# 7
# training_face_8
# 8
# training_face_9
# 9
# training_face_10
# 10
# training_face_11
# 11
# training_face_12
# 12
# training_face_13
# 13
# training_face_14
# 14
# training_face_15
# 15
# training_face_16
# 16
# training_face_17
# 17
# training_face_18
# 18
# training_face_19
# 19
# training_face_20
# 20
# training_face_21
# 21
# training_face_22
# 22
# training_face_23
# 23
# training_face_24
# 24
# training_face_25
# 25
# training_face_26
# 26
# training_face_27
# 27
# training_face_28
# 28
# training_face_29
# 29
# fake
# 0 / 3225
# real
# 0 / 3448
# training_face_30
# 30
# fake
# 0 / 3769
# real
# 0 / 3907
# training_face_31
# 31
# fake
# 0 / 3184
# real
# 0 / 3173
# training_face_32
# 32
# fake
# 0 / 3282
# real
# 0 / 3245
# training_face_33
# 33
# fake
# 0 / 2956
# real
# 0 / 2826
# training_face_34
# 34
# fake
# 0 / 3032
# real
# 2616 / 2997
# training_face_45
# 45
# fake
# ...
